# %% [raw]
# Get to know the data
# ● Perform quick descriptive statistics
#         ○ Mean
#         ○ Median
#         ○ Max
#         ○ Min
#         ○ Variance or Standard Deviation
# ● Look for outliers
# ● Check it out visually
# ● Look at the distribution and variance of data
# ● Further analysis - compare ratios vs. frequencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %store -r co2_in_atmosphere

# %%
co2_in_atmosphere
# Out:
#     year    mean   unc
# 0   1959  315.97  0.12
# 1   1960  316.91  0.12
# 2   1961  317.64  0.12
# 3   1962  318.45  0.12
# 4   1963  318.99  0.12
# 5   1964  319.62  0.12
# 6   1965  320.04  0.12
# 7   1966  321.38  0.12
# 8   1967  322.16  0.12
# 9   1968  323.04  0.12
# 10  1969  324.62  0.12
# 11  1970  325.68  0.12
# 12  1971  326.32  0.12
# 13  1972  327.45  0.12
# 14  1973  329.68  0.12
# 15  1974  330.18  0.12
# 16  1975  331.11  0.12
# 17  1976  332.04  0.12
# 18  1977  333.83  0.12
# 19  1978  335.40  0.12
# 20  1979  336.84  0.12
# 21  1980  338.75  0.12
# 22  1981  340.11  0.12
# 23  1982  341.45  0.12
# 24  1983  343.05  0.12
# 25  1984  344.65  0.12
# 26  1985  346.12  0.12
# 27  1986  347.42  0.12
# 28  1987  349.19  0.12
# 29  1988  351.57  0.12
# ..   ...     ...   ...
# 31  1990  354.39  0.12
# 32  1991  355.61  0.12
# 33  1992  356.45  0.12
# 34  1993  357.10  0.12
# 35  1994  358.83  0.12
# 36  1995  360.82  0.12
# 37  1996  362.61  0.12
# 38  1997  363.73  0.12
# ...

# %% [raw]
# data spans 60 years back from present. (1969-2019)
#
#
#
# at first glance the rate does seem to be increasing with each year.
#
# 1960- mid 1970's: increase by 1.0
# mid 1970's - late 1990's: increase by 1.5
# late 1990's - present: increase by 2.0
#
#
#
# from 1969 to 2019, 95.5 more tonnes per year

# %%
min_value = 315.97
max_value = 411.43
max_value - min_value
# Out:
# 95.45999999999998

# %%
co2_in_atmosphere.plot(x ='year', y='mean', kind = 'scatter')
plt.show()
