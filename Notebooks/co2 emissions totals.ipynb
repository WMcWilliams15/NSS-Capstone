# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %store -r co2_by_country_totals

# %%
co2_by_country_totals.head()
# Out:
#         Entity Code  Year  Annual CO₂ emissions (tonnes )
# 0  Afghanistan  AFG  1949                         14656.0
# 1  Afghanistan  AFG  1950                         84272.0
# 2  Afghanistan  AFG  1951                         91600.0
# 3  Afghanistan  AFG  1952                         91600.0
# 4  Afghanistan  AFG  1953                        106256.0

# %%
co2_by_country_totals = co2_by_country_totals.rename(columns={'Annual CO₂ emissions (tonnes )': 'tonnes'})
co2_by_country_totals
# Out:
#             Entity Code  Year       tonnes
# 0      Afghanistan  AFG  1949     14656.00
# 1      Afghanistan  AFG  1950     84272.00
# 2      Afghanistan  AFG  1951     91600.00
# 3      Afghanistan  AFG  1952     91600.00
# 4      Afghanistan  AFG  1953    106256.00
# 5      Afghanistan  AFG  1954    106256.00
# 6      Afghanistan  AFG  1955    153888.00
# 7      Afghanistan  AFG  1956    183200.00
# 8      Afghanistan  AFG  1957    293120.00
# 9      Afghanistan  AFG  1958    329760.00
# 10     Afghanistan  AFG  1959    384571.42
# 11     Afghanistan  AFG  1960    413883.42
# 12     Afghanistan  AFG  1961    490797.70
# 13     Afghanistan  AFG  1962    688594.27
# 14     Afghanistan  AFG  1963    706735.98
# 15     Afghanistan  AFG  1964    838550.83
# 16     Afghanistan  AFG  1965   1006916.53
# 17     Afghanistan  AFG  1966   1091158.82
# 18     Afghanistan  AFG  1967   1281865.11
# 19     Afghanistan  AFG  1968   1223389.69
# 20     Afghanistan  AFG  1969    941231.98
# ...

# %%
co2_by_country_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20853 entries, 0 to 20852
# Data columns (total 4 columns):
# Entity    20853 non-null object
# Code      18646 non-null object
# Year      20853 non-null int64
# tonnes    20853 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 651.7+ KB

# %% [markdown]
# # World

# %%
total_totals_for_the_years = co2_by_country_totals.groupby('Year').sum().reset_index()
total_totals_for_the_years
# Out:
#      Year        tonnes
# 0    1751  2.805158e+07
# 1    1752  2.806258e+07
# 2    1753  2.806258e+07
# 3    1754  2.807357e+07
# 4    1755  2.808456e+07
# 5    1756  3.001915e+07
# 6    1757  3.003014e+07
# 7    1758  3.004114e+07
# 8    1759  3.005213e+07
# 9    1760  3.005213e+07
# 10   1761  3.292104e+07
# 11   1762  3.293203e+07
# 12   1763  3.294302e+07
# 13   1764  3.295402e+07
# 14   1765  3.296501e+07
# 15   1766  3.677923e+07
# 16   1767  3.679022e+07
# 17   1768  3.680122e+07
# 18   1769  3.681221e+07
# 19   1770  3.682320e+07
# 20   1771  4.083528e+07
# 21   1772  4.084627e+07
# 22   1773  4.085726e+07
# 23   1774  4.086826e+07
# 24   1775  4.087925e+07
# 25   1776  4.511117e+07
# 26   1777  4.512216e+07
# 27   1778  4.513315e+07
# 28   1779  4.514414e+07
# 29   1780  4.516613e+07
# ..    ...           ...
# 237  1988  5.736202e+10
# 238  1989  5.847780e+10
# 239  1990  5.856111e+10
# 240  1991  5.896886e+10
# 241  1992  5.783070e+10
# 242  1993  5.766454e+10
# ...

# %%
total_totals_for_the_years.plot(x='Year', y='tonnes', kind='line')

# %%
total_totals_for_the_years.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23A19B0B8>,
# ...
#       dtype=object)

# %%
def get_aggs(df, col):
    drought_sum = df[col].sum()
    drought_mean = df[col].mean()
    drought_max = df[col].max()
    drought_min = df[col].min()
    drought_var = df[col].var()
    drought_std = df[col].std()
    print(f" sum : {drought_sum}\n mean: {drought_mean}\n max: {drought_max}\n min : {drought_min}\n var: {drought_var}\n std: {drought_std}")

# %%
get_aggs(total_totals_for_the_years, 'tonnes')
# Out:
#  sum : 4025708105198.17
#  mean: 15077558446.43509
#  max: 89472750829.83
#  min : 28051584.0
#  var: 5.7274943314317056e+20
#  std: 23932184044.569992

# %%
co2_by_country_totals.Entity.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Americas (other)',
#        'Andorra', 'Angola', 'Anguilla', 'Antarctic Fisheries',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia and Pacific (other)', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czech Republic', 'Czechoslovakia',
# ...

# %%
total_totals_for_the_years.columns
# Out:
# Index(['Year', 'tonnes'], dtype='object')

# %%
total_bar = co2_by_country_totals.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
total_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # Africa

# %%
africa_list = [  
            'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 
            'Central African Republic (CAR)', 'Chad', 'Comoros', 'Congo', 'Democratic Republic of the Congo', 
            "Cote d'Ivoire", 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea',
            'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho',
            'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique',
            'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
            'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe',
            'Swaziland'
         ]

# %%
def grouping_countries(df, my_list, col1, col2,):
     return df[df[col1].isin(my_list)].groupby(col2).sum().reset_index()

# %%
africa_df_totals = grouping_countries(co2_by_country_totals, africa_list, 'Entity', 'Year')
africa_df_totals
# Out:
#      Year        tonnes
# 0    1884  2.198400e+04
# 1    1885  3.664000e+04
# 2    1886  4.763200e+04
# 3    1887  4.763200e+04
# 4    1888  8.060800e+04
# 5    1889  1.319040e+05
# 6    1890  2.967840e+05
# 7    1891  2.967840e+05
# 8    1892  4.799840e+05
# 9    1893  1.799024e+06
# 10   1894  2.432896e+06
# 11   1895  3.337904e+06
# 12   1896  4.257568e+06
# 13   1897  4.777856e+06
# 14   1898  6.049264e+06
# 15   1899  5.517984e+06
# 16   1900  2.330304e+06
# 17   1901  3.909488e+06
# 18   1902  5.825760e+06
# 19   1903  7.895920e+06
# 20   1904  8.910848e+06
# 21   1905  1.026286e+07
# 22   1906  1.171747e+07
# 23   1907  1.293026e+07
# 24   1908  1.340291e+07
# 25   1909  1.538514e+07
# 26   1910  1.741133e+07
# 27   1911  1.686539e+07
# 28   1912  1.795360e+07
# 29   1913  1.960606e+07
# ..    ...           ...
# 104  1988  7.207296e+08
# 105  1989  6.933895e+08
# 106  1990  6.539803e+08
# 107  1991  6.840340e+08
# 108  1992  6.668233e+08
# 109  1993  7.069066e+08
# ...

# %%
get_aggs(africa_df_totals, 'tonnes')
# Out:
#  sum : 42771079093.98
#  mean: 319187157.4177612
#  max: 1326015577.66
#  min : 21984.0
#  var: 1.6099915942296717e+17
#  std: 401247005.5003117

# %%
africa_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
# Year      134 non-null int64
# tonnes    134 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 2.2 KB

# %%
africa_df_totals.plot(x='Year', y='tonnes', kind='line')

# %%
africa_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23A206320>,
# ...
#       dtype=object)

# %%
africa_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(africa_list)]

# %%
africa_bar = africa_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
africa_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # Asia

# %%
asia = [    
            'Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China',
            'Cyprus', 'Hong Kong', 'Georgia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait',
            'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman',
            'Pakistan', 'Palestine', 'Philippines', 'Qatar', 'Russia', 'Saudi Arabia', 'Singapore', 'South Korea',
            'Sri Lanka', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'Turkmenistan',
            'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen', 'Asia and Pacific (other)', 'New Caledonia'
       ]

# %%
asia_df_totals = grouping_countries(co2_by_country_totals, asia, 'Entity', 'Year')
asia_df_totals
# Out:
#      Year        tonnes
# 0    1751  0.000000e+00
# 1    1752  0.000000e+00
# 2    1753  0.000000e+00
# 3    1754  0.000000e+00
# 4    1755  0.000000e+00
# 5    1756  0.000000e+00
# 6    1757  0.000000e+00
# 7    1758  0.000000e+00
# 8    1759  0.000000e+00
# 9    1760  0.000000e+00
# 10   1761  0.000000e+00
# 11   1762  0.000000e+00
# 12   1763  0.000000e+00
# 13   1764  0.000000e+00
# 14   1765  0.000000e+00
# 15   1766  0.000000e+00
# 16   1767  0.000000e+00
# 17   1768  0.000000e+00
# 18   1769  0.000000e+00
# 19   1770  0.000000e+00
# 20   1771  0.000000e+00
# 21   1772  0.000000e+00
# 22   1773  0.000000e+00
# 23   1774  0.000000e+00
# 24   1775  0.000000e+00
# 25   1776  0.000000e+00
# 26   1777  0.000000e+00
# 27   1778  0.000000e+00
# 28   1779  0.000000e+00
# 29   1780  0.000000e+00
# ..    ...           ...
# 237  1988  1.167096e+10
# 238  1989  1.193292e+10
# 239  1990  1.218845e+10
# 240  1991  1.243649e+10
# 241  1992  1.232256e+10
# 242  1993  1.259957e+10
# ...

# %%
get_aggs(asia_df_totals, 'tonnes')
# Out:
#  sum : 745710303966.4202
#  mean: 2792922486.765619
#  max: 26357572356.150005
#  min : 0.0
#  var: 3.5775238072697905e+19
#  std: 5981240512.861685

# %%
asia_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 2 columns):
# Year      267 non-null int64
# tonnes    267 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 4.2 KB

# %%
asia_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 2 columns):
# Year      267 non-null int64
# tonnes    267 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 4.2 KB

# %%
asia_df_totals.plot(x='Year', y="tonnes", kind='line')

# %%
asia_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23B962A58>,
# ...
#       dtype=object)

# %%
asia_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(asia)]

# %%
asia_bar = asia_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
asia_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # Europe

# %%
europe = [
            'Albania', 'Andorra', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium', 'Bosnia and Herzegovina',
            'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany',
            'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein',
            'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland',
            'Portugal', 'Romania', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
            'Turkey', 'Ukraine', 'United Kingdom', 'Vatican City', 'Bonaire Sint Eustatius and Saba', 'Czech Republic',
            'Czechoslovakia', 'Gibraltar', 'Greenland', 'Sint Maarten (Dutch part)', 'Macedonia'
        ]

# %%
europe_df_totals = grouping_countries(co2_by_country_totals, europe, 'Entity', 'Year') 
europe_df_totals
# Out:
#      Year        tonnes
# 0    1751  9.350528e+06
# 1    1752  9.354192e+06
# 2    1753  9.354192e+06
# 3    1754  9.357856e+06
# 4    1755  9.361520e+06
# 5    1756  1.000638e+07
# 6    1757  1.001005e+07
# 7    1758  1.001371e+07
# 8    1759  1.001738e+07
# 9    1760  1.001738e+07
# 10   1761  1.097368e+07
# 11   1762  1.097734e+07
# 12   1763  1.098101e+07
# 13   1764  1.098467e+07
# 14   1765  1.098834e+07
# 15   1766  1.225974e+07
# 16   1767  1.226341e+07
# 17   1768  1.226707e+07
# 18   1769  1.227074e+07
# 19   1770  1.227440e+07
# 20   1771  1.361176e+07
# 21   1772  1.361542e+07
# 22   1773  1.361909e+07
# 23   1774  1.362275e+07
# 24   1775  1.362642e+07
# 25   1776  1.503706e+07
# 26   1777  1.504072e+07
# 27   1778  1.504438e+07
# 28   1779  1.504805e+07
# 29   1780  1.505538e+07
# ..    ...           ...
# 237  1988  6.183025e+09
# 238  1989  6.226946e+09
# 239  1990  6.150665e+09
# 240  1991  6.002877e+09
# 241  1992  5.606532e+09
# 242  1993  5.381291e+09
# ...

# %%
get_aggs(europe_df_totals, 'tonnes')
# Out:
#  sum : 429311559519.4899
#  mean: 1607908462.619813
#  max: 6253667552.34
#  min : 9350528.0
#  var: 4.1282912703238564e+18
#  std: 2031819694.3439288

# %%
europe_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 2 columns):
# Year      267 non-null int64
# tonnes    267 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 4.2 KB

# %%
europe_df_totals.plot(x='Year', y='tonnes', kind='line')

# %%
europe_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23BC9FCF8>,
# ...
#       dtype=object)

# %%
europe_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(europe)]

# %%
europe_bar = europe_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
europe_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # North America

# %%
co2_by_country_totals.Entity.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Americas (other)',
#        'Andorra', 'Angola', 'Anguilla', 'Antarctic Fisheries',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia and Pacific (other)', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czech Republic', 'Czechoslovakia',
# ...

# %%
north_america = [ 
                    'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica',
                    'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
                    'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines',
                    'Trinidad and Tobago', 'United States', 'Americas (other)', 'Aruba', 'Bermuda', 'Curacao', 'Guadeloupe',
                    'Martinique'
                ]

# %%
north_america_df_totals = grouping_countries(co2_by_country_totals, north_america, 'Entity', 'Year') 
north_america_df_totals
# Out:
#      Year        tonnes
# 0    1751  0.000000e+00
# 1    1752  0.000000e+00
# 2    1753  0.000000e+00
# 3    1754  0.000000e+00
# 4    1755  0.000000e+00
# 5    1756  0.000000e+00
# 6    1757  0.000000e+00
# 7    1758  0.000000e+00
# 8    1759  0.000000e+00
# 9    1760  0.000000e+00
# 10   1761  0.000000e+00
# 11   1762  0.000000e+00
# 12   1763  0.000000e+00
# 13   1764  0.000000e+00
# 14   1765  0.000000e+00
# 15   1766  0.000000e+00
# 16   1767  0.000000e+00
# 17   1768  0.000000e+00
# 18   1769  0.000000e+00
# 19   1770  0.000000e+00
# 20   1771  0.000000e+00
# 21   1772  0.000000e+00
# 22   1773  0.000000e+00
# 23   1774  0.000000e+00
# 24   1775  0.000000e+00
# 25   1776  0.000000e+00
# 26   1777  0.000000e+00
# 27   1778  0.000000e+00
# 28   1779  0.000000e+00
# 29   1780  0.000000e+00
# ..    ...           ...
# 237  1988  7.175628e+09
# 238  1989  7.372092e+09
# 239  1990  7.465937e+09
# 240  1991  7.424982e+09
# 241  1992  7.585146e+09
# 242  1993  7.738293e+09
# ...

# %%
get_aggs(north_america_df_totals, 'tonnes')
# Out:
#  sum : 555623555453.69
#  mean: 2080987099.0774903
#  max: 9546250848.88
#  min : 0.0
#  var: 8.832788425000844e+18
#  std: 2972000744.4482317

# %%
north_america_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 2 columns):
# Year      267 non-null int64
# tonnes    267 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 4.2 KB

# %%
north_america_df_totals.plot(x ='Year', y='tonnes', kind = 'line')
plt.show()

# %%
north_america_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23BEDAB00>,
# ...
#       dtype=object)

# %%
north_america_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(north_america)]

# %%
north_america_bar = north_america_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
north_america_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # South America

# %%
south_america = [
                    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru',
                    'Suriname', 'Uruguay', 'Venezuela'
                ]

# %%
south_america_df_totals = grouping_countries(co2_by_country_totals, south_america, 'Entity', 'Year')
south_america_df_totals
# Out:
#      Year        tonnes
# 0    1884  3.664000e+03
# 1    1885  3.664000e+03
# 2    1886  7.328000e+03
# 3    1887  1.091872e+06
# 4    1888  8.976800e+05
# 5    1889  1.762384e+06
# 6    1890  1.381328e+06
# 7    1891  9.856160e+05
# 8    1892  1.450944e+06
# 9    1893  1.601168e+06
# 10   1894  2.033520e+06
# 11   1895  2.828608e+06
# 12   1896  2.879904e+06
# 13   1897  2.758992e+06
# 14   1898  3.176688e+06
# 15   1899  3.715296e+06
# 16   1900  3.165696e+06
# 17   1901  6.401008e+06
# 18   1902  7.379296e+06
# 19   1903  7.676080e+06
# 20   1904  8.665360e+06
# 21   1905  9.211296e+06
# 22   1906  1.232936e+07
# 23   1907  1.268477e+07
# 24   1908  1.488683e+07
# 25   1909  1.340658e+07
# 26   1910  1.724645e+07
# 27   1911  1.916272e+07
# 28   1912  1.999078e+07
# 29   1913  2.112296e+07
# ..    ...           ...
# 104  1988  5.797641e+08
# 105  1989  5.793222e+08
# 106  1990  5.828999e+08
# 107  1991  5.890570e+08
# 108  1992  5.983910e+08
# 109  1993  6.330871e+08
# ...

# %%
get_aggs(south_america_df_totals, 'tonnes')
# Out:
#  sum : 39624939803.67999
#  mean: 295708505.99761194
#  max: 1210871082.68
#  min : 3664.0
#  var: 1.251203076812631e+17
#  std: 353723490.4289834

# %%
south_america_df_totals.plot(x ='Year', y='tonnes', kind = 'line')
plt.show()

# %%
south_america_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23C180BA8>,
# ...
#       dtype=object)

# %%
south_america_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(south_america)]

# %%
south_america_bar = south_america_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
south_america_bar.plot(x='Entity', y='tonnes', kind='bar')

# %% [markdown]
# # Austrialia

# %%
austrialia = [
                'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand', 'Palau',
                'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu'
            ]

# %%
austrialia_df_totals = grouping_countries(co2_by_country_totals, austrialia, 'Entity', 'Year')
austrialia_df_totals
# Out:
#      Year        tonnes
# 0    1860  2.784640e+05
# 1    1861  5.092960e+05
# 2    1862  3.554080e+05
# 3    1863  3.993760e+05
# 4    1864  2.674720e+05
# 5    1865  4.213600e+05
# 6    1866  6.961600e+05
# 7    1867  8.940160e+05
# 8    1868  7.328000e+05
# 9    1869  6.412000e+05
# 10   1870  6.008960e+05
# 11   1871  6.924960e+05
# 12   1872  7.071520e+05
# 13   1873  8.683680e+05
# 14   1874  8.903520e+05
# 15   1875  8.280640e+05
# 16   1876  9.306560e+05
# 17   1877  1.066224e+06
# 18   1878  1.322704e+06
# 19   1879  1.960240e+06
# 20   1880  2.861584e+06
# 21   1881  2.502512e+06
# 22   1882  2.839600e+06
# 23   1883  3.352560e+06
# 24   1884  3.631024e+06
# 25   1885  4.034064e+06
# 26   1886  4.067040e+06
# 27   1887  4.272224e+06
# 28   1888  4.891440e+06
# 29   1889  4.737552e+06
# ..    ...           ...
# 128  1988  2.898458e+08
# 129  1989  3.064183e+08
# 130  1990  3.076042e+08
# 131  1991  3.095188e+08
# 132  1992  3.166446e+08
# 133  1993  3.205251e+08
# ...

# %%
austrialia_df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 2 columns):
# Year      158 non-null int64
# tonnes    158 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 2.5 KB

# %%
get_aggs(austrialia_df_totals, 'tonnes')
# Out:
#  sum : 19379634660.33
#  mean: 122655915.57170887
#  max: 459203001.89000005
#  min : 267472.0
#  var: 2.254646586181543e+16
#  std: 150154806.32272625

# %%
austrialia_df_totals.plot(x ='Year', y='tonnes', kind = 'line')
plt.show()

# %%
austrialia_df_totals.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E23C368588>,
# ...
#       dtype=object)

# %%
austrialia_countries_df = co2_by_country_totals.loc[co2_by_country_totals['Entity'].isin(austrialia)]

# %%
austrialia_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
# Out:
#               Entity    Year        tonnes
# 0          Australia  306283  1.736081e+10
# 5        New Zealand  272650  1.779162e+09
# 7   Papua New Guinea  134878  1.524822e+08
# 1               Fiji  134878  4.516083e+07
# 6              Palau  125118  1.101224e+07
# 9    Solomon Islands  130977  7.165127e+06
# 8              Samoa  134878  6.445614e+06
# 4              Nauru  107487  4.678403e+06
# 12           Vanuatu  111412  4.315060e+06
# 10             Tonga  134878  3.965652e+06
# 3   Marshall Islands   52117  2.266040e+06
# 2           Kiribati  113373  1.913895e+06
# 11            Tuvalu   56098  2.569226e+05

# %%
austrialia_bar = austrialia_countries_df.groupby('Entity').sum().reset_index().sort_values(by='tonnes', ascending=False)
austrialia_bar.plot(x='Entity', y='tonnes', kind='bar')

# %%
conditions = [
    (co2_by_country_totals['Entity'].isin(africa_list)),
    (co2_by_country_totals['Entity'].isin(asia)),
    (co2_by_country_totals['Entity'].isin(austrialia)),
    (co2_by_country_totals['Entity'].isin(europe)),
    (co2_by_country_totals['Entity'].isin(north_america)),
    (co2_by_country_totals['Entity'].isin(south_america))
            ]

choices = ['Africa','Asia','Australia', 'Europe','North_America', 'South_America']

co2_by_country_totals['continent'] = np.select(conditions, choices, default='null')

# %%
co2_by_country_totals_bar = co2_by_country_totals.groupby('continent').sum().reset_index().sort_values(by='tonnes', ascending=False)
co2_by_country_totals_bar.plot(x='continent', y='tonnes', kind='bar')

# %%
co2_by_country_totals.to_csv('all_country_co2_data.csv')
