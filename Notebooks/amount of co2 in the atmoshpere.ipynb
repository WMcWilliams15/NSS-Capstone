# %% [raw]
# Get to know the data
# ● Perform quick descriptive statistics
#         ○ Mean
#         ○ Median
#         ○ Max
#         ○ Min
#         ○ Variance or Standard Deviation
# ● Look for outliers
# ● Check it out visually
# ● Look at the distribution and variance of data
# ● Further analysis - compare ratios vs. frequencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %store -r co2_in_atmosphere

# %%
co2_in_atmosphere
# Out:
#     year    mean   unc  increase_from_last_year
# 0   1959  315.97  0.12                     0.00
# 1   1960  316.91  0.12                     0.94
# 2   1961  317.64  0.12                     0.73
# 3   1962  318.45  0.12                     0.81
# 4   1963  318.99  0.12                     0.54
# 5   1964  319.62  0.12                     0.63
# 6   1965  320.04  0.12                     0.42
# 7   1966  321.38  0.12                     1.34
# 8   1967  322.16  0.12                     0.78
# 9   1968  323.04  0.12                     0.88
# 10  1969  324.62  0.12                     1.58
# 11  1970  325.68  0.12                     1.06
# 12  1971  326.32  0.12                     0.64
# 13  1972  327.45  0.12                     1.13
# 14  1973  329.68  0.12                     2.23
# 15  1974  330.18  0.12                     0.50
# 16  1975  331.11  0.12                     0.93
# 17  1976  332.04  0.12                     0.93
# 18  1977  333.83  0.12                     1.79
# 19  1978  335.40  0.12                     1.57
# 20  1979  336.84  0.12                     1.44
# 21  1980  338.75  0.12                     1.91
# 22  1981  340.11  0.12                     1.36
# 23  1982  341.45  0.12                     1.34
# 24  1983  343.05  0.12                     1.60
# 25  1984  344.65  0.12                     1.60
# 26  1985  346.12  0.12                     1.47
# 27  1986  347.42  0.12                     1.30
# 28  1987  349.19  0.12                     1.77
# 29  1988  351.57  0.12                     2.38
# ..   ...     ...   ...                      ...
# 31  1990  354.39  0.12                     1.27
# 32  1991  355.61  0.12                     1.22
# 33  1992  356.45  0.12                     0.84
# 34  1993  357.10  0.12                     0.65
# 35  1994  358.83  0.12                     1.73
# 36  1995  360.82  0.12                     1.99
# 37  1996  362.61  0.12                     1.79
# 38  1997  363.73  0.12                     1.12
# 39  1998  366.70  0.12                     2.97
# 40  1999  368.38  0.12                     1.68
# 41  2000  369.55  0.12                     1.17
# 42  2001  371.14  0.12                     1.59
# 43  2002  373.28  0.12                     2.14
# 44  2003  375.80  0.12                     2.52
# 45  2004  377.52  0.12                     1.72
# 46  2005  379.80  0.12                     2.28
# 47  2006  381.90  0.12                     2.10
# 48  2007  383.79  0.12                     1.89
# 49  2008  385.60  0.12                     1.81
# 50  2009  387.43  0.12                     1.83
# 51  2010  389.90  0.12                     2.47
# 52  2011  391.65  0.12                     1.75
# 53  2012  393.85  0.12                     2.20
# 54  2013  396.52  0.12                     2.67
# 55  2014  398.65  0.12                     2.13
# 56  2015  400.83  0.12                     2.18
# 57  2016  404.24  0.12                     3.41
# 58  2017  406.55  0.12                     2.31
# 59  2018  408.52  0.12                     1.97
# 60  2019  411.43  0.12                     2.91
#
# [61 rows x 4 columns]

# %%
co2_in_atmosphere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
# year                       61 non-null int64
# mean                       61 non-null float64
# unc                        61 non-null float64
# increase_from_last_year    61 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 2.0 KB

# %%
def get_aggs(df, col):
    drought_sum = df[col].sum()
    drought_mean = df[col].mean()
    drought_max = df[col].max()
    drought_min = df[col].min()
    drought_var = df[col].var()
    drought_std = df[col].std()
    print(f" sum : {drought_sum}\n mean: {drought_mean}\n max: {drought_max}\n min : {drought_min}\n var: {drought_var}\n std: {drought_std}")

# %%
get_aggs(co2_in_atmosphere, 'mean')
# Out:
#  sum : 21675.350000000002
#  mean: 355.33360655737715
#  max: 411.43
#  min : 315.97
#  var: 800.4062067759564
#  std: 28.291451125312687

# %%
co2_in_atmosphere.plot(x ='year', y='mean', kind = 'scatter')
plt.show()

# %%
co2_in_atmosphere.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FE65CCAC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FE65D41748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FE6604E860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FE660739B0>]],
#       dtype=object)

# %% [raw]
# data spans 60 years back from present. (1969-2019)
#
#
# at first glance the rate (mean's) does seem to be increasing with each year.
# 1960- mid 1970's: increase by 1.0
# mid 1970's - late 1990's: increase by 1.5
# late 1990's - present: increase by 2.0
#
#
# from 1969 to 2019, 95.5 more tonnes per year
#
#
# each year is an average of its months.
#
#
# co2 is measured in ppm's.
#
#
# maybe try to get an idea of the scale of one ppm.
