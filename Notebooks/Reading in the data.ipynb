# %%
import pandas as pd

# %% [raw]
# Get to know the data
# ● Perform quick descriptive statistics
#         ○ Mean
#         ○ Median
#         ○ Max
#         ○ Min
#         ○ Variance or Standard Deviation
# ● Look for outliers
# ● Check it out visually
# ● Look at the distribution and variance of data
# ● Further analysis - compare ratios vs. frequencies

# %% [markdown]
# # This is a breakdown of the co2 for the US, years (1990-Present)

# %%
co2_breakdown = pd.read_csv('C:/Users/wmcwi/Documents/NSS-Capstone/Data/breakdown_of_co2.csv')
co2_breakdown
# Out:
#           Economic Sector         1990         1991         1992         1993  \
# 0          Transportation  1527.071188  1480.927212  1540.530936  1577.519112
# 1  Electricity generation  1875.593659  1871.622530  1886.593971  1962.354970
# 2                Industry  1628.676867  1602.045952  1633.075916  1602.408186
# 3             Agriculture   598.967218   589.682520   590.570246   618.614388
# 4              Commercial   428.668347   435.610013   431.178707   424.627494
# 5             Residential   344.701666   354.247606   360.821161   372.164956
# 6        U.S. territories    33.321186    39.123871    37.315650    39.085447
# 7                   Total  6437.000131  6373.259703  6480.086588  6596.774554
#
#           1994         1995         1996         1997         1998  ...  \
# 0  1632.153745  1667.328361  1723.497937  1750.008339  1792.365801  ...
# 1  1987.151999  2003.872715  2076.854716  2143.022602  2229.562822  ...
# ...

# %%
co2_breakdown = co2_breakdown.transpose().reset_index()
co2_breakdown = co2_breakdown.iloc[1:]

co2_breakdown.head()
# Out:
#   index        0        1        2        3        4        5        6  \
# 1  1990  1527.07  1875.59  1628.68  598.967  428.668  344.702  33.3212
# 2  1991  1480.93  1871.62  1602.05  589.683   435.61  354.248  39.1239
# 3  1992  1540.53  1886.59  1633.08   590.57  431.179  360.821  37.3156
# 4  1993  1577.52  1962.35  1602.41  618.614  424.627  372.165  39.0854
# 5  1994  1632.15  1987.15  1628.11  605.833  428.066  362.939  41.4794
#
#          7
# 1     6437
# 2  6373.26
# 3  6480.09
# 4  6596.77
# 5  6685.73

# %%
co2_breakdown = co2_breakdown.rename(columns = {'index':'Year', 
                                                0:'Transportation', 
                                                1:'Electricity_generation', 
                                                2:'Industry', 3:'Agriculture', 
                                                4:'Commercial', 
                                                5:'Residential', 
                                                6:'U.S._Territories', 
                                                7:'Total'})

# %%
co2_breakdown
# Out:
#     Year Transportation Electricity_generation Industry Agriculture  \
# 1   1990        1527.07                1875.59  1628.68     598.967
# 2   1991        1480.93                1871.62  1602.05     589.683
# 3   1992        1540.53                1886.59  1633.08      590.57
# 4   1993        1577.52                1962.35  1602.41     618.614
# 5   1994        1632.15                1987.15  1628.11     605.833
# 6   1995        1667.33                2003.87  1646.81     618.138
# 7   1996         1723.5                2076.85  1674.91     625.073
# 8   1997        1750.01                2143.02  1672.32     613.575
# 9   1998        1792.37                2229.56  1644.51     620.526
# 10  1999        1863.37                2243.62   1592.6     611.522
# 11  2000        1901.23                2349.16  1583.77     596.409
# 12  2001        1881.78                2309.67  1532.49     617.193
# 13  2002        1923.22                2325.54   1517.4     620.001
# ...

# %%
# %store co2_breakdown
del co2_breakdown
# Out:
# Stored 'co2_breakdown' (DataFrame)

# %% [markdown]
# # This is the the amount of co2 by country, years (1800-present)

# %%
co2_by_country = pd.read_csv('C:/Users/wmcwi/Documents/NSS-Capstone/Data/co2_emissions_by_country.csv', usecols=[0,2,3])
co2_by_country.head()
# Out:
#         Entity  Year  Per capita CO₂ emissions (tonnes per capita)
# 0  Afghanistan  1800                                           0.0
# 1  Afghanistan  1801                                           0.0
# 2  Afghanistan  1802                                           0.0
# 3  Afghanistan  1803                                           0.0
# 4  Afghanistan  1804                                           0.0

# %%
# %store co2_by_country
del co2_by_country
# Out:
# Stored 'co2_by_country' (DataFrame)

# %% [markdown]
# # This is the count of natural disasters

# %%
natural_disasters = pd.read_csv('C:/Users/wmcwi/Documents/NSS-Capstone/Data/count_of_natural_disasters.csv', usecols=[0,2,3])
natural_disasters.head()
# Out:
#                   Entity  Year  \
# 0  All natural disasters  1900
# 1  All natural disasters  1901
# 2  All natural disasters  1902
# 3  All natural disasters  1903
# 4  All natural disasters  1904
#
#    Number of reported natural disasters (reported disasters)
# 0                                                  5
# 1                                                  2
# 2                                                  9
# 3                                                  8
# 4                                                  2

# %%
natural_disasters.Entity.unique()
# Out:
# array(['All natural disasters', 'Drought', 'Earthquake',
#        'Extreme temperature', 'Extreme weather', 'Flood', 'Impact',
#        'Landslide', 'Mass movement (dry)', 'Volcanic activity',
#        'Wildfire'], dtype=object)

# %%
# %store natural_disasters
del natural_disasters
# Out:
# Stored 'natural_disasters' (DataFrame)

# %% [markdown]
# # This is the avg land temps

# %%
average_land_temps = pd.read_csv('C:/Users/wmcwi/Documents/NSS-Capstone/Data/global_land_temps.csv', usecols=[0,1,2,3,15])
average_land_temps.head()
# Out:
#    Year  Glob  NHem  SHem  Farenheight
# 0  1880 -0.16 -0.27 -0.05        -0.29
# 1  1881 -0.08 -0.16  0.00        -0.14
# 2  1882 -0.10 -0.19 -0.01        -0.18
# 3  1883 -0.16 -0.26 -0.07        -0.29
# 4  1884 -0.28 -0.41 -0.15        -0.50

# %%
# %store average_land_temps
del average_land_temps
# Out:
# Stored 'average_land_temps' (DataFrame)

# %% [markdown]
# # This is the table for the levels of co2 in the atmoshpere

# %%
co2_in_atmosphere = pd.read_csv('C:/Users/wmcwi/Documents/NSS-Capstone/Data/levels_of_co2_in_atmosphere.csv', skiprows=55)
co2_in_atmosphere.head()
# Out:
#    year    mean   unc  increase_from_last_year
# 0  1959  315.97  0.12                     0.00
# 1  1960  316.91  0.12                     0.94
# 2  1961  317.64  0.12                     0.73
# 3  1962  318.45  0.12                     0.81
# 4  1963  318.99  0.12                     0.54

# %%
# %store co2_in_atmosphere
del co2_in_atmosphere
# Out:
# Stored 'co2_in_atmosphere' (DataFrame)

# %%
temps = pd.read_csv('../Data/avg_temps.csv', skiprows=4)
temps.head()
# Out:
#    Year  Value
# 0  1880  -0.05
# 1  1881   0.06
# 2  1882  -0.15
# 3  1883  -0.20
# 4  1884  -0.28

# %%
temps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 2 columns):
# Year     141 non-null int64
# Value    141 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 2.3 KB

# %%
# %store temps
del temps
# Out:
# Stored 'temps' (DataFrame)
